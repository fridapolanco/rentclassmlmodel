# %% [markdown]
# # Assigment 1 - ML2 - FNPD

# %% [markdown]
# We will do a **rent classification higher than 850** on properties in Madrid based on an Idealista dataset. To create this model we will use **gradient boost**.

# %% [markdown]
# * Address : which includes the address in Spanish
# * Price : In Euros €
# * Rooms : Number of rooms in the houses, for Studios the values are NaN
# * Squared meters : the squared meters of the renting house
# * Floor : The floor in which the housing is
# * Link : The hyperlink of the referencing house
# * Summary : A brief description in Spanish of the house, including information such as the floor
# * Distric : Malasaña, Moncloa, Lavapies, Chueca, Chamartin and La Latina.
# * Type : Flat, Studio, Duplex and Attic
# * Pool : True or False
# * Furniture : True or False
# * Exterior : True or False
# * Elevator : True or False

# %%
import pandas as pd 
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV


from sklearn.metrics import (
    make_scorer,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve,
)

import joblib

from sklearn.base import BaseEstimator

import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Importing the dataset

# %%
data = pd.read_csv("madrid_idealista.csv")

# %%
data.head()
# Out:
#                                              Address  Price  Rooms  \
# 0                  calle Aguarón, Valdemarín, Madrid  900.0    NaN
# 1         calle de Luisa Fernanda, Argüelles, Madrid  700.0    NaN
# 2                   calle de Irún, Argüelles, Madrid  900.0    NaN
# 3  avenida del Doctor Federico Rubio y Galí, 88, ...  850.0    NaN
# 4                                 Valdemarín, Madrid  795.0    NaN
#
#    Squared_meters  Floor                                  Link  \
# 0              55      2  www.idealista.com/inmueble/98588378/
# 1              50      4  www.idealista.com/inmueble/91350410/
# 2              73      2  www.idealista.com/inmueble/98145156/
# 3              41      0  www.idealista.com/inmueble/98614584/
# 4              42      1  www.idealista.com/inmueble/97899849/
#
#                                              Summary    Distric    Type  \
# 0  \nChrystie & Didie ofrece en Exclusiva. Loft m...  Chamartin  Studio
# 1  \nDisponible a principios de septiembre. Alqui...  Chamartin  Studio
# 2  \nExcelente estudio, junto a la estación de Pr...  Chamartin  Studio
# 3  \nSe alquila estudio amueblado de 40 m2 recién...  Chamartin  Studio
# 4  \nARAVACA-VALDEMARIN.\nExclusivo Loft de 40 M2...  Chamartin  Studio
#
#     Pool  Furniture  Exterior  Elevator
# 0  False      False      True      True
# 1  False      False     False      True
# 2  False      False      True      True
# 3  False       True      True      True
# 4  False      False      True      True

# %% [markdown]
# Deleting columns that are irrelevant = Link, Summary & Address

# %%
data = data.drop(columns=["Link", "Summary","Address"])

# %%
data.head()
# Out:
#    Price  Rooms  Squared_meters  Floor    Distric    Type   Pool  Furniture  \
# 0  900.0    NaN              55      2  Chamartin  Studio  False      False
# 1  700.0    NaN              50      4  Chamartin  Studio  False      False
# 2  900.0    NaN              73      2  Chamartin  Studio  False      False
# 3  850.0    NaN              41      0  Chamartin  Studio  False       True
# 4  795.0    NaN              42      1  Chamartin  Studio  False      False
#
#    Exterior  Elevator
# 0      True      True
# 1     False      True
# 2      True      True
# 3      True      True
# 4      True      True

# %% [markdown]
# ### EDA

# %%
#Checking for NULLS in data 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Price           517 non-null    float64
#  1   Rooms           430 non-null    float64
#  2   Squared_meters  517 non-null    int64
#  3   Floor           517 non-null    int64
#  4   Distric         517 non-null    object
#  5   Type            517 non-null    object
#  6   Pool            517 non-null    bool
#  7   Furniture       517 non-null    bool
#  8   Exterior        517 non-null    bool
#  9   Elevator        517 non-null    bool
# dtypes: bool(4), float64(2), int64(2), object(2)
# memory usage: 26.4+ KB

# %%
#Filling NaNs with 1; since our documentation explains that studios have NaNs in column rooms
data.Rooms.fillna(1, inplace=True)

# %%
data.head()
# Out:
#    Price  Rooms  Squared_meters  Floor    Distric    Type   Pool  Furniture  \
# 0  900.0    1.0              55      2  Chamartin  Studio  False      False
# 1  700.0    1.0              50      4  Chamartin  Studio  False      False
# 2  900.0    1.0              73      2  Chamartin  Studio  False      False
# 3  850.0    1.0              41      0  Chamartin  Studio  False       True
# 4  795.0    1.0              42      1  Chamartin  Studio  False      False
#
#    Exterior  Elevator
# 0      True      True
# 1     False      True
# 2      True      True
# 3      True      True
# 4      True      True

# %%
data.Price.describe()
# Out:
# count    517.000000
# mean     867.226306
# std       91.485379
# min      500.000000
# 25%      800.000000
# 50%      900.000000
# 75%      945.000000
# max      995.000000
# Name: Price, dtype: float64

# %%
#Defining target variable
data["Target"] = np.where((data.Price > 850), 1, 0)

# %%
#Ensuring balanced target
data.Target.value_counts()
# Out:
# Target
# 1    307
# 0    210
# Name: count, dtype: int64

# %%
target_counts = data['Target'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(target_counts, labels=target_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Target Column')
plt.show()

# %%
#Deleting column price as this is replaced by column 'Target'
data = data.drop(columns=["Price"])

# %%
data.head()
# Out:
#    Rooms  Squared_meters  Floor    Distric    Type   Pool  Furniture  \
# 0    1.0              55      2  Chamartin  Studio  False      False
# 1    1.0              50      4  Chamartin  Studio  False      False
# 2    1.0              73      2  Chamartin  Studio  False      False
# 3    1.0              41      0  Chamartin  Studio  False       True
# 4    1.0              42      1  Chamartin  Studio  False      False
#
#    Exterior  Elevator  Target
# 0      True      True       1
# 1     False      True       0
# 2      True      True       1
# 3      True      True       0
# 4      True      True       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rooms           517 non-null    float64
#  1   Squared_meters  517 non-null    int64
#  2   Floor           517 non-null    int64
#  3   Distric         517 non-null    object
#  4   Type            517 non-null    object
#  5   Pool            517 non-null    bool
#  6   Furniture       517 non-null    bool
#  7   Exterior        517 non-null    bool
#  8   Elevator        517 non-null    bool
#  9   Target          517 non-null    int32
# dtypes: bool(4), float64(1), int32(1), int64(2), object(2)
# memory usage: 24.4+ KB

# %%
#Correcting datatype of boolean columns to have 0s & 1s
#These columns; though categorical, will be considered as num when choosing which columns will be Ohed or Scaled
data = data.astype(
    {
        "Pool": float,
        "Furniture": float,
        "Exterior": float,
        "Elevator": float,
        "Target": float,
        "Squared_meters": float
    }
)

# %%
data.head()
# Out:
#    Rooms  Squared_meters  Floor    Distric    Type  Pool  Furniture  Exterior  \
# 0    1.0            55.0      2  Chamartin  Studio   0.0        0.0       1.0
# 1    1.0            50.0      4  Chamartin  Studio   0.0        0.0       0.0
# 2    1.0            73.0      2  Chamartin  Studio   0.0        0.0       1.0
# 3    1.0            41.0      0  Chamartin  Studio   0.0        1.0       1.0
# 4    1.0            42.0      1  Chamartin  Studio   0.0        0.0       1.0
#
#    Elevator  Target
# 0       1.0     1.0
# 1       1.0     0.0
# 2       1.0     1.0
# 3       1.0     0.0
# 4       1.0     0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rooms           517 non-null    float64
#  1   Squared_meters  517 non-null    float64
#  2   Floor           517 non-null    int64
#  3   Distric         517 non-null    object
#  4   Type            517 non-null    object
#  5   Pool            517 non-null    float64
#  6   Furniture       517 non-null    float64
#  7   Exterior        517 non-null    float64
#  8   Elevator        517 non-null    float64
#  9   Target          517 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 40.5+ KB

# %%
#Basic statistics on our columns 
data.describe()
# Out:
#             Rooms  Squared_meters       Floor        Pool   Furniture  \
# count  517.000000      517.000000  517.000000  517.000000  517.000000
# mean     1.423598       55.870406    2.110251    0.065764    0.117988
# std      0.707425       14.381857    1.659315    0.248109    0.322907
# min      1.000000       16.000000    0.000000    0.000000    0.000000
# 25%      1.000000       47.000000    1.000000    0.000000    0.000000
# 50%      1.000000       55.000000    2.000000    0.000000    0.000000
# 75%      2.000000       65.000000    3.000000    0.000000    0.000000
# max      4.000000       98.000000    6.000000    1.000000    1.000000
#
#          Exterior  Elevator      Target
# count  517.000000     517.0  517.000000
# mean     0.725338       1.0    0.593810
# std      0.446776       0.0    0.491596
# min      0.000000       1.0    0.000000
# 25%      0.000000       1.0    0.000000
# 50%      1.000000       1.0    1.000000
# 75%      1.000000       1.0    1.000000
# max      1.000000       1.0    1.000000

# %%
data.columns.to_list()
# Out:
# ['Rooms',
#  'Squared_meters',
#  'Floor',
#  'Distric',
#  'Type',
#  'Pool',
#  'Furniture',
#  'Exterior',
#  'Elevator',
#  'Target']

# %%
#Visualizing the data
sns.pairplot(data, hue = 'Target', vars = ['Rooms','Squared_meters','Floor','Pool','Furniture','Exterior','Elevator'])
# Out:
# c:\Users\frida\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\frida\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\frida\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\frida\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\frida\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\frida\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\frida\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Checking correlations 
data[['Rooms',
 'Squared_meters',
 'Floor',
 'Pool',
 'Furniture',
 'Exterior']].corr()
# Out:
#                    Rooms  Squared_meters     Floor      Pool  Furniture  \
# Rooms           1.000000        0.601045 -0.071232 -0.159023   0.111652
# Squared_meters  0.601045        1.000000 -0.252449  0.000221  -0.086840
# Floor          -0.071232       -0.252449  1.000000 -0.045890  -0.060495
# Pool           -0.159023        0.000221 -0.045890  1.000000  -0.097039
# Furniture       0.111652       -0.086840 -0.060495 -0.097039   1.000000
# Exterior       -0.005207        0.253231 -0.257088  0.163266   0.010133
#
#                 Exterior
# Rooms          -0.005207
# Squared_meters  0.253231
# Floor          -0.257088
# Pool            0.163266
# Furniture       0.010133
# Exterior        1.000000

# %% [markdown]
# ### Build a model with pipelines

# %% [markdown]
# Train test split

# %%
X = data.drop(columns=["Target"])
y = data["Target"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=99
)

# %% [markdown]
# Column transformer for pre-processing
# * OHE categorical data
# * MinMaxScale int data

# %%
categorical_columns = X.select_dtypes(["O", "int"]).columns
numerical_columns = X.select_dtypes(["float"]).columns

# %%
categorical_columns
# Out:
# Index(['Floor', 'Distric', 'Type'], dtype='object')

# %%
numerical_columns
# Out:
# Index(['Rooms', 'Squared_meters', 'Pool', 'Furniture', 'Exterior', 'Elevator'], dtype='object')

# %%
preprocessing = ColumnTransformer(
    [
        ("ohe", OneHotEncoder(sparse_output=False), categorical_columns),
        ("scaler", MinMaxScaler(), numerical_columns),
    ],
    remainder="drop",  # this can be "drop", "passthrough", or another Estimator
)

# %%
X_train.head()
# Out:
#      Rooms  Squared_meters  Floor   Distric    Type  Pool  Furniture  \
# 179    3.0            80.0      4    Chueca    Flat   0.0        0.0
# 69     1.0            35.0      0  Malasaña  Studio   0.0        0.0
# 15     1.0            41.0      0    Chueca  Studio   0.0        1.0
# 442    1.0            50.0      3  Malasaña    Flat   0.0        1.0
# 509    1.0            50.0      6   Moncloa    Flat   0.0        0.0
#
#      Exterior  Elevator
# 179       1.0       1.0
# 69        1.0       1.0
# 15        1.0       1.0
# 442       1.0       1.0
# 509       0.0       1.0

# %% [markdown]
# Gradient boosting model with parameter tuning

# %%
gbc = GradientBoostingClassifier()
pipeline = Pipeline(steps=[("preprocessing", preprocessing), ("gbc", gbc)])

# %%
grid = RandomizedSearchCV(
    pipeline,
    param_distributions={"gbc__n_estimators":[1,5,10,20,40],'gbc__max_depth':[3,4,5,6]},
    n_iter=10,
    scoring="f1",
    cv=5,
    n_jobs=-1,
)

# %% [markdown]
# Apply whole process to original data

# %%
grid.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('ohe',
#                                                                                OneHotEncoder(sparse_output=False),
#                                                                                Index(['Floor', 'Distric', 'Type'], dtype='object')),
#                                                                               ('scaler',
#                                                                                MinMaxScaler(),
#                                                                                Index(['Rooms', 'Squared_meters', 'Pool', 'Furniture', 'Exterior', 'Elevator'], dtype='object'))])),
#                                              ('gbc',
#                                               GradientBoostingClassifier())]),
#                    n_jobs=-1,
#                    param_distributions={'gbc__max_depth': [3, 4, 5, 6],
#                                         'gbc__n_estimators': [1, 5, 10, 20,
#                                                               40]},
#                    scoring='f1')

# %% [markdown]
# Evaluation on train

# %%
pred = grid.predict(X_train)
probas = grid.predict_proba(X_train)

# %%
precision_test = precision_score(y_train, pred, pos_label=1)        #pos_label = what our target positive is
recall_test = recall_score(y_train, pred, pos_label=1)
f1_test = f1_score(y_train, pred, pos_label=1)
roc_auc_test = roc_auc_score(y_train, probas[:, 1])

# %%
print(f"Train Precision: {round(precision_test,3)}")
print(f"Train Recall: {round(recall_test,3)}")
print(f"Train F1: {round(f1_test,3)}")
print(f"Train ROC_AUC: {round(roc_auc_test,3)}")
# Out:
# Train Precision: 0.949
# Train Recall: 0.944
# Train F1: 0.946
# Train ROC_AUC: 0.99

# %% [markdown]
# Evaluation on test

# %%
pred = grid.predict(X_test)
probas = grid.predict_proba(X_test)

# %%
precision_test = precision_score(y_test, pred, pos_label=1)
recall_test = recall_score(y_test, pred, pos_label=1)
f1_test = f1_score(y_test, pred, pos_label=1)
roc_auc_test = roc_auc_score(y_test, probas[:, 1])

# %%
print(f"Test Precision: {round(precision_test,3)}")
print(f"Test Recall: {round(recall_test,3)}")
print(f"Test F1: {round(f1_test,3)}")
print(f"Test ROC_AUC: {round(roc_auc_test,3)}")
# Out:
# Test Precision: 0.911
# Test Recall: 0.891
# Test F1: 0.901
# Test ROC_AUC: 0.975

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[56,  8],
#        [10, 82]], dtype=int64)

# %%
cm= confusion_matrix(y_test, pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=True, yticklabels=True)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Saving the model

# %%
# get best model

best_model = grid.best_estimator_

# Extract the final estimator from the pipeline
final_estimator = best_model.named_steps['gbc']  


final_estimator
# Out:
# GradientBoostingClassifier(max_depth=4, n_estimators=40)

# %%
# grid best parameters

grid.best_params_
# Out:
# {'gbc__n_estimators': 40, 'gbc__max_depth': 4}

# %%
# To see choosen parameters 
grid.best_estimator_.named_steps
# Out:
# {'preprocessing': ColumnTransformer(transformers=[('ohe', OneHotEncoder(sparse_output=False),
#                                   Index(['Floor', 'Distric', 'Type'], dtype='object')),
#                                  ('scaler', MinMaxScaler(),
#                                   Index(['Rooms', 'Squared_meters', 'Pool', 'Furniture', 'Exterior', 'Elevator'], dtype='object'))]),
#  'gbc': GradientBoostingClassifier(max_depth=4, n_estimators=40)}

# %%
#Ensure we're saving witht the correct datatype
type(best_model)
# Out:
# sklearn.pipeline.Pipeline

# %%
# write the pipeline to disk

joblib.dump(best_model, "model.joblib")
# Out:
# ['model.joblib']

# %%
grid.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('ohe',
#                                                                                OneHotEncoder(sparse_output=False),
#                                                                                Index(['Floor', 'Distric', 'Type'], dtype='object')),
#                                                                               ('scaler',
#                                                                                MinMaxScaler(),
#                                                                                Index(['Rooms', 'Squared_meters', 'Pool', 'Furniture', 'Exterior', 'Elevator'], dtype='object'))])),
#                                              ('gbc',
#                                               GradientBoostingClassifier())]),
#                    n_jobs=-1,
#                    param_distributions={'gbc__max_depth': [3, 4, 5, 6],
#                                         'gbc__n_estimators': [1, 5, 10, 20,
#                                                               40]},
#                    scoring='f1')>

# %%
#Double checking the saved model has a predict method
if isinstance(best_model, BaseEstimator) and hasattr(best_model, 'predict'):
    print("The final estimator has a predict method.")
else:
    print("The final estimator does not have a predict method.")
# Out:
# The final estimator has a predict method.

# %%
#Testing it worls for predicting
test_input = pd.DataFrame(
    [[2, 80, 2, 'Malasaña', 'Flat', 1, 1, 1, 1]],
    columns=['Floor', 'Squared_meters', 'Rooms', 'Distric', 'Type', 'Pool', 'Furniture', 'Exterior', 'Elevator']
)

print(grid.predict(test_input)[0])
# Out:
# 1.0
